# %%
import numpy
s1=[1,7,3,6,0,2]
a1=numpy.array(s1)
with open('source1.txt', 'w') as f:
  f.write(str(a1))
  f.close()
s2=[9,3,6,5,7,1]
a2=numpy.array(s2)
with open('source2.txt','w') as f:
  f.write(str(a2))
  f.close()
f=open('source1.txt','r')
data1 = f.read()
f=open('source2.txt','r')
data2 = f.read()
final_list = list1 + list2
list=[final_list]
a3=numpy.array(list)
with open('Target.txt','w') as f:
  f.write(str(a3))
f=open('Target.txt','r')
print(f.read())
def mergeandsort(source1, source2, Target):
    with open(source1, 'r') as s1, open(source2, 'r') as s2, open(Target, 'w') as d:
        l = list(s1) + list(s2)
        l.sort(reverse=true)  
        c = ''.join(l)
        d.write(c)
# Out:
# [[1 7 3 6 0 2 9 3 6 5 7 1]]

# %%
l1 = [2,3,8]
l2 = [6,1,0,4,9]
file1 = open("Source1.txt",'w+')
file2 = open("Source2.txt",'w+')
file3 = open("Target.txt",'w+')
for i in l1:
  try:
    file1.write(str(i)+" ")
  except NameError:
    print("file doesn’t exist")
for i in l2:
  try:
    file2.write(str(i)+" ")
  except NameError:
    print("file does not exist")
file1.seek(0)
file2.seek(0)
l3 = []
l4 = []
temp= ""
for i in file1.read():
  if i==' ':
    l3.append(int(temp))
    temp=""
  else:
    temp+=i
for i in file2.read():
  if i==' ':
    l4.append(int(temp))
    temp=""
  else:
    temp+=i
    l3.sort()
    l4.sort()
    i = 0
    j = 0
    res = []
    while(i<len(l3) and j<len(l4)):
      if l4[j] > l3[i]:
        res.append(l3[i])
        i = i + 1
      else:
        res.append(l4[j])
        j = j + 1
        while i < len(l3):
          res.append(l3[i])
          i = i + 1
        while j < len(l4):
          res.append(l4[j])
          j = j + 1
for i in res:
  try:
    file3.write(str(i)+" ")
  except NameError:
    print("file does not exist")
file3.seek(0)
print(file3.read())
file1.close()
file2.close()
file3.close()
# Out:
# 0 2 3 8 1 4 6

# %%
file1 = open("Encrypt.txt",'w+')
file2 = open("Decrypt.txt",'w+')
str = input("Enter a string : ")
type = int(input("Enter 1 for encryption,2 for decryption : "))
#taking key as 3
key = 3
if type == 1:
  temp = ""
for i in str:
  temp = temp + chr(ord(i)+key)
  try:
    file1.write(temp)
    file1.seek(0)
  except NameError:
    print("file does not exist")
else:
  temp = ""
for i in str:
  temp = temp + chr(ord(i)-key)
  try:
    file1.write(temp)
    file1.seek(0)
  except NameError:
    print("file does not exist")
print("The result is",file1.read())
# Out:
# Enter a string : I am anurag
# Enter 1 for encryption,2 for decryption : 1
# The result is F^j^kro^d

# %%
file1 = open("File1.txt",'w+')
file2 = open("File2.txt",'w+')
str1 = "I am anurag"
try:
  file1.write(str1)
except NameError:
  print("File doesn't exist")
try:
  file2.write(" and i am from hisar")
except NameError:
  print("File doesn't exist")
file3 = open("File3.txt",'w+')
try:
  file1.seek(0)
  file2.seek(0)
  file3.write(file1.read()+file2.read())
  file3.seek(0)
  print(file3.read())
  file1.close()
  file2.close()
  file3.close()
except NameError:
  print("File doesn't exist")
# Out:
# I am anurag and i am from hisar

# %%
str = """i am anurag and i am from hisar"""
try:
  file1 = open("File1.txt",'w+')
  file1.write(str)
  file1.seek(0)
  temp = file1.readlines()
except NameError:
  print("file does not exist")
line = 0
word = 0
c = 0
for i in temp:
  ln = i.split()
  line = line + 1
  word = word + len(ln)
for cr in ln:
  c = c + len(cr)
print(f"words are : {word}")
print(f"words are : {line}")
print(f"words are : {c}")
file1.close()
# Out:
# words are : 8
# words are : 1
# words are : 24

# %%
str = "i am Anurag patter and my age is 19 eroll no 201b056 "
file1 = open("File1.txt",'w+')
try:
  file1.write(str)
  file1.seek(0)
  temp = file1.read()
except NameError:
  print("file does not exist")
dict = {}
for i in temp:
  if i == ' ':
    continue
  if i in dict:
    dict[i]+=1
  else:
    dict[i] = 1
for i,j in dict.items():
  print(f"Freq of {i} is {j}")
  file1.close()
# Out:
# Freq of i is 2
# Freq of a is 5
# Freq of m is 2
# Freq of A is 1
# Freq of n is 3
# Freq of u is 1
# Freq of r is 3
# Freq of g is 2
# Freq of p is 1
# Freq of t is 2
# Freq of e is 3
# Freq of d is 1
# Freq of y is 1
# Freq of s is 1
# Freq of 1 is 2
# Freq of 9 is 1
# Freq of o is 2
# Freq of l is 2
# Freq of 2 is 1
# Freq of 0 is 2
# Freq of b is 1
# Freq of 5 is 1
# Freq of 6 is 1

# %%
# Printing details of students with same state
import csv
f=open("STD record.csv")
r=csv.reader(f)
D10={}
for s in r:
  if s:
    D10[s[0]]=[s[1],s[2],s[3],s[4],s[5],s[6]]
f.close()

# %%
import csv
f=open("STD record.csv")
r=csv.reader(f)
D12={}
for s in r:
  if s:
    D1[s[0]]=s[0],s[1]
    D2[s[0]]=s[6]
print("Students with email host as gmail: ")
for i, j in D2.items():
  if j =="gmail":
    print(D1[i])
